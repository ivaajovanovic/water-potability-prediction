# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('water_potability.csv')

# %%
# filling null values
df['ph'] = df.groupby('Potability')['ph'].transform(lambda x: x.fillna(x.mean()))
df['Sulfate'] = df.groupby('Potability')['Sulfate'].transform(lambda x: x.fillna(x.mean()))
df['Trihalomethanes'] = df.groupby('Potability')['Trihalomethanes'].transform(lambda x: x.fillna(x.mean()))

# %%
# handling outliers - capping method
feature_cols = df.drop('Potability', axis=1).columns
for col in feature_cols:
    lower_bound = df[col].quantile(0.01)
    upper_bound = df[col].quantile(0.99)
    df[col] = np.clip(df[col], lower_bound, upper_bound)

# %%
print("Descriptive statistics AFTER handling outliers:")
display(df.describe())
# Out:
# Descriptive statistics AFTER handling outliers:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  3276.000000  3276.000000   3276.000000  3276.000000  3276.000000
# mean      7.082241   196.377131  21986.861995     7.121080   333.843353
# std       1.417990    32.148545   8593.336883     1.539526    34.901822
# min       3.442510   114.236366   5416.238724     3.203082   237.136957
# 25%       6.277673   176.850538  15666.690297     6.127421   317.094638
# 50%       7.085378   196.967627  20927.833607     7.130299   334.564290
# 75%       7.870050   216.667456  27332.762127     8.114887   350.385756
# max      10.812925   278.062602  45974.106490    10.967153   429.028139
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3276.000000  3276.000000  3276.000000
# mean     426.094862       14.283331        66.419610     3.966520     0.390110
# std       79.584453        3.249256        15.396203     0.765986     0.487849
# min      269.422947        6.452487        28.524993     2.161414     0.000000
# 25%      365.734414       12.065801        56.647656     3.439711     0.000000
# 50%      421.884968       14.218338        66.303555     3.955028     0.000000
# 75%      481.792304       16.557652        76.666609     4.500320     1.000000
# max      617.626558       22.090049       104.606299     5.741640     1.000000

# %%
output_filename = 'water_potability_clean.csv'
df.to_csv(output_filename, index=False)
